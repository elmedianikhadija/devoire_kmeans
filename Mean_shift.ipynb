# %% [markdown]
# <a href="https://colab.research.google.com/github/elmedianikhadija/devoire_kmeans_Mean_shift/blob/main/Mean_shift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mean Shift est un algorithme de clustering hiérarchique. Contrairement aux algorithmes d’apprentissage automatique supervisés, le clustering tente de regrouper des données sans avoir d’abord été entraîné sur des données étiquetées. Le clustering est utilisé dans une grande variété d’applications telles que les moteurs de recherche, les classements académiques et la médecine. Contrairement à K-Means, lorsque vous utilisez Mean Shift, vous n’avez pas besoin de connaître le nombre de catégories (clusters) à l’avance.

# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.datasets import make_blobs

# %matplotlib inline

# %% [markdown]
# Nous générons nos propres données en utilisant la méthode.make_blobs

# %%
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, _ = make_blobs(n_samples=10000, centers=centers, cluster_std=0.6)

# %% [markdown]
# Après avoir entraîné le modèle, nous stockons les coordonnées des centres de cluster.

# %%
# Compute clustering with MeanShift

# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)
# Out:
# number of estimated clusters : 3

# %%
# Plot result
import matplotlib.pyplot as plt
from itertools import cycle

plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %% [markdown]
# Nous générons nos propres données en utilisant la méthode.make_blobs

# %%
clusters = [[1,1,1],[5,5,5],[3,10,10]]
X, _ = make_blobs(n_samples = 150, centers = clusters, cluster_std = 0.60)

# %% [markdown]
# Après avoir entraîné le modèle, nous stockons les coordonnées des centres de cluster.

# %%
ms = MeanShift()
ms.fit(X)
cluster_centers = ms.cluster_centers_

# %% [markdown]
# Enfin, nous traçons les points de données et les centroïdes dans un graphique 3D.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2], marker='o')
ax.scatter(cluster_centers[:,0], cluster_centers[:,1], cluster_centers[:,2], marker='x', color='red', s=300, linewidth=5, zorder=10)
plt.show()
